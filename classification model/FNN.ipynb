# %%
import pandas as pd
from tensorflow import keras
from sklearn.model_selection import train_test_split
from data import BodyPart
import tensorflow as tf

# %%
def load_csv(csv_path):
    df = pd.read_csv(csv_path)
    df.drop(['filename'],axis=1, inplace=True)
    classes = df.pop('class_name').unique()
    y = df.pop('class_no')
    
    X = df.astype('float64')
    y = keras.utils.to_categorical(y)
    
    return X, y, classes

# %%
def get_center_point(landmarks, left_bodypart, right_bodypart):
    """Calculates the center point of the two given landmarks."""
    left = tf.gather(landmarks, left_bodypart.value, axis=1)
    right = tf.gather(landmarks, right_bodypart.value, axis=1)
    center = left * 0.5 + right * 0.5
    return center

# %%
def get_pose_size(landmarks, torso_size_multiplier=2.5):
    """Calculates pose size.

    It is the maximum of two values:
    * Torso size multiplied by `torso_size_multiplier`
    * Maximum distance from pose center to any pose landmark
    """
    # Hips center
    hips_center = get_center_point(landmarks, BodyPart.LEFT_HIP, 
                                 BodyPart.RIGHT_HIP)

    # Shoulders center
    shoulders_center = get_center_point(landmarks, BodyPart.LEFT_SHOULDER,
                                      BodyPart.RIGHT_SHOULDER)

    # Torso size as the minimum body size
    torso_size = tf.linalg.norm(shoulders_center - hips_center)
    # Pose center
    pose_center_new = get_center_point(landmarks, BodyPart.LEFT_HIP, 
                                     BodyPart.RIGHT_HIP)
    pose_center_new = tf.expand_dims(pose_center_new, axis=1)
    # Broadcast the pose center to the same size as the landmark vector to
    # perform substraction
    pose_center_new = tf.broadcast_to(pose_center_new,
                                    [tf.size(landmarks) // (17*2), 17, 2])

    # Dist to pose center
    d = tf.gather(landmarks - pose_center_new, 0, axis=0,
                name="dist_to_pose_center")
    # Max dist to pose center
    max_dist = tf.reduce_max(tf.linalg.norm(d, axis=0))

    # Normalize scale
    pose_size = tf.maximum(torso_size * torso_size_multiplier, max_dist)
    return pose_size

# %%
def normalize_pose_landmarks(landmarks):
    """Normalizes the landmarks translation by moving the pose center to (0,0) and
    scaling it to a constant pose size.
  """
  # Move landmarks so that the pose center becomes (0,0)
    pose_center = get_center_point(landmarks, BodyPart.LEFT_HIP, 
                                 BodyPart.RIGHT_HIP)

    pose_center = tf.expand_dims(pose_center, axis=1)
    # Broadcast the pose center to the same size as the landmark vector to perform
    # substraction
    pose_center = tf.broadcast_to(pose_center, 
                                [tf.size(landmarks) // (17*2), 17, 2])
    landmarks = landmarks - pose_center

    # Scale the landmarks to a constant pose size
    pose_size = get_pose_size(landmarks)
    landmarks /= pose_size
    return landmarks

# %%
def landmarks_to_embedding(landmarks_and_scores):
    """Converts the input landmarks into a pose embedding."""
    # Reshape the flat input into a matrix with shape=(17, 3)
    reshaped_inputs = keras.layers.Reshape((17, 3))(landmarks_and_scores)

    # Normalize landmarks 2D
    landmarks = normalize_pose_landmarks(reshaped_inputs[:, :, :2])
    # Flatten the normalized landmark coordinates into a vector
    embedding = keras.layers.Flatten()(landmarks)
    return embedding

# %%
def preprocess_data(X_train):
    processed_X_train = []
    for i in range(X_train.shape[0]):
        embedding = landmarks_to_embedding(tf.reshape(tf.convert_to_tensor(X_train.iloc[i]), (1, 51)))
        processed_X_train.append(tf.reshape(embedding, (34)))
    return tf.convert_to_tensor(processed_X_train)

# %%
X, y, class_names = load_csv('train_data.csv')
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.15)
X_test, y_test, _ = load_csv('test_data.csv')

# %%
processed_X_train = preprocess_data(X_train)
processed_X_val =  preprocess_data(X_val)
processed_X_test = preprocess_data(X_test)

# %%
inputs = tf.keras.Input(shape=(34, ))
layer = keras.layers.Dense(128, activation=tf.nn.relu6)(inputs)
layer = keras.layers.Dropout(0.5)(layer)
layer = keras.layers.Dense(64, activation=tf.nn.relu6)(layer)
layer = keras.layers.Dropout(0.5)(layer)
outputs = keras.layers.Dense(len(class_names), activation="softmax")(layer)

# %%
model = keras.Model(inputs, outputs)

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
# checkpoint_path = "weights.best.hdf5"
# checkpoint = keras.callbacks.ModelCheckpoint(checkpoint_path,
#                              monitor='val_accuracy',
#                              verbose=1,
#                              save_best_only=True,
#                              mode='max')
# earlystopping = keras.callbacks.EarlyStopping(monitor='val_accuracy', 
#                                        patience=20)

# %%
history = model.fit(processed_X_train, y_train,
                    epochs=200,
                    batch_size=16,
                    validation_data=(processed_X_val, y_val))
# Out:
# Epoch 1/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.3089 - loss: 1.9184 - val_accuracy: 0.6828 - val_loss: 1.2392
# Epoch 2/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5159 - loss: 1.2945 - val_accuracy: 0.7665 - val_loss: 0.8172
# Epoch 3/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6383 - loss: 0.9748 - val_accuracy: 0.8106 - val_loss: 0.6242
# Epoch 4/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7238 - loss: 0.8004 - val_accuracy: 0.8238 - val_loss: 0.4948
# Epoch 5/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7472 - loss: 0.6580 - val_accuracy: 0.8855 - val_loss: 0.4034
# Epoch 6/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7610 - loss: 0.6675 - val_accuracy: 0.8899 - val_loss: 0.3470
# Epoch 7/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7975 - loss: 0.5528 - val_accuracy: 0.9427 - val_loss: 0.2879
# Epoch 8/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8264 - loss: 0.5035 - val_accuracy: 0.9207 - val_loss: 0.2593
# Epoch 9/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8397 - loss: 0.4566 - val_accuracy: 0.9427 - val_loss: 0.2259
# Epoch 10/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8620 - loss: 0.4151 - val_accuracy: 0.9515 - val_loss: 0.2015
# Epoch 11/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8737 - loss: 0.3647 - val_accuracy: 0.9515 - val_loss: 0.1749
# Epoch 12/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8697 - loss: 0.3696 - val_accuracy: 0.9604 - val_loss: 0.1730
# Epoch 13/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8703 - loss: 0.3617 - val_accuracy: 0.9515 - val_loss: 0.1522
# Epoch 14/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8919 - loss: 0.3226 - val_accuracy: 0.9692 - val_loss: 0.1301
# Epoch 15/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2679 - val_accuracy: 0.9648 - val_loss: 0.1254
# Epoch 16/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9154 - loss: 0.2733 - val_accuracy: 0.9604 - val_loss: 0.1211
# Epoch 17/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9060 - loss: 0.2880 - val_accuracy: 0.9648 - val_loss: 0.1025
# Epoch 18/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9072 - loss: 0.2704 - val_accuracy: 0.9648 - val_loss: 0.0996
# Epoch 19/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9179 - loss: 0.2441 - val_accuracy: 0.9736 - val_loss: 0.0951
# Epoch 20/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9361 - loss: 0.2168 - val_accuracy: 0.9780 - val_loss: 0.0855
# Epoch 21/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9347 - loss: 0.2206 - val_accuracy: 0.9824 - val_loss: 0.0889
# Epoch 22/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9442 - loss: 0.1841 - val_accuracy: 0.9824 - val_loss: 0.0856
# Epoch 23/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9425 - loss: 0.2059 - val_accuracy: 0.9692 - val_loss: 0.0886
# Epoch 24/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9430 - loss: 0.1959 - val_accuracy: 0.9824 - val_loss: 0.0770
# Epoch 25/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9457 - loss: 0.1776 - val_accuracy: 0.9824 - val_loss: 0.0660
# Epoch 26/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9523 - loss: 0.1700 - val_accuracy: 0.9780 - val_loss: 0.0626
# Epoch 27/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9453 - loss: 0.1747 - val_accuracy: 0.9780 - val_loss: 0.0623
# Epoch 28/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9427 - loss: 0.1625 - val_accuracy: 0.9736 - val_loss: 0.0637
# Epoch 29/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9530 - loss: 0.1734 - val_accuracy: 0.9780 - val_loss: 0.0616
# Epoch 30/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9463 - loss: 0.1723 - val_accuracy: 0.9824 - val_loss: 0.0558
# Epoch 31/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9432 - loss: 0.1646 - val_accuracy: 0.9780 - val_loss: 0.0568
# Epoch 32/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9535 - loss: 0.1638 - val_accuracy: 0.9780 - val_loss: 0.0504
# Epoch 33/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9513 - loss: 0.1563 - val_accuracy: 0.9824 - val_loss: 0.0521
# Epoch 34/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9673 - loss: 0.1276 - val_accuracy: 0.9824 - val_loss: 0.0481
# Epoch 35/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9647 - loss: 0.1197 - val_accuracy: 0.9780 - val_loss: 0.0533
# Epoch 36/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9593 - loss: 0.1243 - val_accuracy: 0.9780 - val_loss: 0.0514
# Epoch 37/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9689 - loss: 0.1237 - val_accuracy: 0.9780 - val_loss: 0.0456
# Epoch 38/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9652 - loss: 0.1188 - val_accuracy: 0.9780 - val_loss: 0.0487
# Epoch 39/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9505 - loss: 0.1442 - val_accuracy: 0.9692 - val_loss: 0.0500
# Epoch 40/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9698 - loss: 0.0953 - val_accuracy: 0.9736 - val_loss: 0.0503
# Epoch 41/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9679 - loss: 0.1104 - val_accuracy: 0.9736 - val_loss: 0.0443
# Epoch 42/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9608 - loss: 0.1041 - val_accuracy: 0.9824 - val_loss: 0.0483
# Epoch 43/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9726 - loss: 0.1032 - val_accuracy: 0.9824 - val_loss: 0.0463
# Epoch 44/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9671 - loss: 0.1121 - val_accuracy: 0.9868 - val_loss: 0.0419
# Epoch 45/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9715 - loss: 0.0938 - val_accuracy: 0.9868 - val_loss: 0.0402
# Epoch 46/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9690 - loss: 0.0904 - val_accuracy: 0.9824 - val_loss: 0.0416
# Epoch 47/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9602 - loss: 0.1032 - val_accuracy: 0.9736 - val_loss: 0.0434
# Epoch 48/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9673 - loss: 0.0904 - val_accuracy: 0.9824 - val_loss: 0.0404
# Epoch 49/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9812 - loss: 0.0760 - val_accuracy: 0.9824 - val_loss: 0.0375
# Epoch 50/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9801 - loss: 0.0836 - val_accuracy: 0.9780 - val_loss: 0.0417
# Epoch 51/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9797 - loss: 0.0681 - val_accuracy: 0.9868 - val_loss: 0.0406
# Epoch 52/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9668 - loss: 0.0891 - val_accuracy: 0.9824 - val_loss: 0.0329
# Epoch 53/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.
200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9775 - loss: 0.0689 - val_accuracy: 0.9912 - val_loss: 0.0349
# Epoch 86/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9958 - loss: 0.0286 - val_accuracy: 0.9868 - val_loss: 0.0398
# Epoch 87/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9912 - loss: 0.0353 - val_accuracy: 0.9868 - val_loss: 0.0369
# Epoch 88/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9795 - loss: 0.0555 - val_accuracy: 0.9912 - val_loss: 0.0305
# Epoch 89/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9864 - loss: 0.0507 - val_accuracy: 0.9912 - val_loss: 0.0295
# Epoch 90/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9872 - loss: 0.0507 - val_accuracy: 0.9868 - val_loss: 0.0475
# Epoch 91/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9885 - loss: 0.0503 - val_accuracy: 0.9868 - val_loss: 0.0341
# Epoch 92/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9892 - loss: 0.0408 - val_accuracy: 0.9912 - val_loss: 0.0397
# Epoch 93/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9904 - loss: 0.0362 - val_accuracy: 0.9868 - val_loss: 0.0497
# Epoch 94/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9798 - loss: 0.0582 - val_accuracy: 0.9868 - val_loss: 0.0607
# Epoch 95/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9801 - loss: 0.0478 - val_accuracy: 0.9868 - val_loss: 0.0510
# Epoch 96/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9877 - loss: 0.0397 - val_accuracy: 0.9868 - val_loss: 0.0438
# Epoch 97/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9851 - loss: 0.0353 - val_accuracy: 0.9868 - val_loss: 0.0484
# Epoch 98/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9870 - loss: 0.0394 - val_accuracy: 0.9868 - val_loss: 0.0470
# Epoch 99/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9867 - loss: 0.0421 - val_accuracy: 0.9868 - val_loss: 0.0502
# Epoch 100/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9879 - loss: 0.0352 - val_accuracy: 0.9868 - val_loss: 0.0437
# Epoch 101/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9855 - loss: 0.0376 - val_accuracy: 0.9868 - val_loss: 0.0367
# Epoch 102/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9833 - loss: 0.0610 - val_accuracy: 0.9912 - val_loss: 0.0370
# Epoch 103/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9901 - loss: 0.0385 - val_accuracy: 0.9868 - val_loss: 0.0410
# Epoch 104/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9960 - loss: 0.0204 - val_accuracy: 0.9868 - val_loss: 0.0334
# Epoch 105/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9916 - loss: 0.0253 - val_accuracy: 0.9868 - val_loss: 0.0392
# Epoch 106/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9906 - loss: 0.0329 - val_accuracy: 0.9912 - val_loss: 0.0385
# Epoch 107/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9856 - loss: 0.0436 - val_accuracy: 0.9868 - val_loss: 0.0462
# Epoch 108/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9918 - loss: 0.0373 - val_accuracy: 0.9868 - val_loss: 0.0501
# Epoch 109/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9874 - loss: 0.0438 - val_accuracy: 0.9868 - val_loss: 0.0453
# Epoch 110/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9892 - loss: 0.0329 - val_accuracy: 0.9868 - val_loss: 0.0446
# Epoch 111/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9807 - loss: 0.0503 - val_accuracy: 0.9912 - val_loss: 0.0406
# Epoch 112/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9854 - loss: 0.0414 - val_accuracy: 0.9912 - val_loss: 0.0400
# Epoch 113/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9889 - loss: 0.0356 - val_accuracy: 0.9912 - val_loss: 0.0409
# Epoch 114/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9871 - loss: 0.0346 - val_accuracy: 0.9912 - val_loss: 0.0354
# Epoch 115/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9915 - loss: 0.0318 - val_accuracy: 0.9912 - val_loss: 0.0368
# Epoch 116/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.
200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9940 - loss: 0.0251 - val_accuracy: 0.9868 - val_loss: 0.0609
# Epoch 148/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9916 - loss: 0.0322 - val_accuracy: 0.9868 - val_loss: 0.0554
# Epoch 149/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9913 - loss: 0.0225 - val_accuracy: 0.9868 - val_loss: 0.0518
# Epoch 150/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9829 - loss: 0.0512 - val_accuracy: 0.9868 - val_loss: 0.0655
# Epoch 151/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9948 - loss: 0.0175 - val_accuracy: 0.9912 - val_loss: 0.0539
# Epoch 152/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9922 - loss: 0.0227 - val_accuracy: 0.9868 - val_loss: 0.0511
# Epoch 153/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9945 - loss: 0.0160 - val_accuracy: 0.9868 - val_loss: 0.0467
# Epoch 154/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9890 - loss: 0.0246 - val_accuracy: 0.9868 - val_loss: 0.0576
# Epoch 155/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9915 - loss: 0.0203 - val_accuracy: 0.9868 - val_loss: 0.0533
# Epoch 156/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9929 - loss: 0.0269 - val_accuracy: 0.9912 - val_loss: 0.0531
# Epoch 157/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9913 - loss: 0.0252 - val_accuracy: 0.9912 - val_loss: 0.0526
# Epoch 158/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9938 - loss: 0.0229 - val_accuracy: 0.9912 - val_loss: 0.0355
# Epoch 159/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9898 - loss: 0.0380 - val_accuracy: 0.9912 - val_loss: 0.0365
# Epoch 160/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9956 - loss: 0.0191 - val_accuracy: 0.9868 - val_loss: 0.0506
# Epoch 161/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9935 - loss: 0.0185 - val_accuracy: 0.9912 - val_loss: 0.0410
# Epoch 162/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9911 - loss: 0.0213 - val_accuracy: 0.9912 - val_loss: 0.0382
# Epoch 163/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9900 - loss: 0.0208 - val_accuracy: 0.9868 - val_loss: 0.0509
# Epoch 164/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9896 - loss: 0.0272 - val_accuracy: 0.9912 - val_loss: 0.0485
# Epoch 165/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9962 - loss: 0.0255 - val_accuracy: 0.9868 - val_loss: 0.0414
# Epoch 166/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9875 - loss: 0.0258 - val_accuracy: 0.9868 - val_loss: 0.0537
# Epoch 167/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9886 - loss: 0.0404 - val_accuracy: 0.9912 - val_loss: 0.0372
# Epoch 168/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9911 - loss: 0.0230 - val_accuracy: 0.9868 - val_loss: 0.0348
# Epoch 169/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9966 - loss: 0.0198 - val_accuracy: 0.9868 - val_loss: 0.0408
# Epoch 170/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9952 - loss: 0.0163 - val_accuracy: 0.9912 - val_loss: 0.0439
# Epoch 171/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9942 - loss: 0.0227 - val_accuracy: 0.9868 - val_loss: 0.0525
# Epoch 172/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9851 - loss: 0.0304 - val_accuracy: 0.9868 - val_loss: 0.0581
# Epoch 173/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9959 - loss: 0.0138 - val_accuracy: 0.9912 - val_loss: 0.0590
# Epoch 174/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9932 - loss: 0.0172 - val_accuracy: 0.9868 - val_loss: 0.0586
# Epoch 175/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9956 - loss: 0.0196 - val_accuracy: 0.9868 - val_loss: 0.0506
# Epoch 176/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9946 - loss: 0.0164 - val_accuracy: 0.9912 - val_loss: 0.0455
# Epoch 177/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9962 - loss: 0.0199 - val_accuracy: 0.9912 - val_loss: 0.0439
# Epoch 178/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9928 - loss: 0.0245 - val_accuracy: 0.9912 - val_loss: 0.0504
# Epoch 179/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9861 - loss: 0.0320 - val_accuracy: 0.9868 - val_loss: 0.0470
# Epoch 180/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9949 - loss: 0.0196 - val_accuracy: 0.9912 - val_loss: 0.0418
# Epoch 181/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9929 - loss: 0.0183 - val_accuracy: 0.9912 - val_loss: 0.0371
# Epoch 182/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9919 - loss: 0.0261 - val_accuracy: 0.9912 - val_loss: 0.0431
# Epoch 183/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9893 - loss: 0.0271 - val_accuracy: 0.9868 - val_loss: 0.0500
# Epoch 184/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9942 - loss: 0.0262 - val_accuracy: 0.9868 - val_loss: 0.0508
# Epoch 185/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9954 - loss: 0.0135 - val_accuracy: 0.9868 - val_loss: 0.0517
# Epoch 186/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9919 - loss: 0.0210 - val_accuracy: 0.9912 - val_loss: 0.0520
# Epoch 187/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9956 - loss: 0.0181 - val_accuracy: 0.9868 - val_loss: 0.0707
# Epoch 188/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9924 - loss: 0.0281 - val_accuracy: 0.9912 - val_loss: 0.0506
# Epoch 189/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9856 - loss: 0.0281 - val_accuracy: 0.9912 - val_loss: 0.0537
# Epoch 190/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9958 - loss: 0.0144 - val_accuracy: 0.9868 - val_loss: 0.0690
# Epoch 191/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9932 - loss: 0.0145 - val_accuracy: 0.9868 - val_loss: 0.0663
# Epoch 192/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9994 - loss: 0.0130 - val_accuracy: 0.9868 - val_loss: 0.0661
# Epoch 193/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9967 - loss: 0.0144 - val_accuracy: 0.9868 - val_loss: 0.0609
# Epoch 194/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9946 - loss: 0.0177 - val_accuracy: 0.9868 - val_loss: 0.0693
# Epoch 195/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9933 - loss: 0.0211 - val_accuracy: 0.9868 - val_loss: 0.0626
# Epoch 196/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9883 - loss: 0.0338 - val_accuracy: 0.9912 - val_loss: 0.0516
# Epoch 197/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9977 - loss: 0.0162 - val_accuracy: 0.9912 - val_loss: 0.0591
# Epoch 198/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9919 - loss: 0.0192 - val_accuracy: 0.9868 - val_loss: 0.0559
# Epoch 199/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9977 - loss: 0.0087 - val_accuracy: 0.9868 - val_loss: 0.0540
# Epoch 200/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9880 - loss: 0.0468 - val_accuracy: 0.9912 - val_loss: 0.0368

# %%
print('-----------------EVAUATION----------------')
loss, accuracy = model.evaluate(processed_X_test, y_test)
print('LOSS: ', loss)
print("Test ACCURACY: ", accuracy)
# Out:
# -----------------EVAUATION----------------
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9992 - loss: 0.0024
# LOSS:  0.01495716255158186
# Test ACCURACY:  0.9954389929771423

# %%
loss, accuracy = model.evaluate(processed_X_train, y_train)
print('LOSS: ', loss)
print("Train ACCURACY: ", accuracy)
# Out:
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 898us/step - accuracy: 1.0000 - loss: 8.5090e-04
# LOSS:  0.0008978276746347547
# Train ACCURACY:  1.0

# %%
loss, accuracy = model.evaluate(processed_X_val, y_val)
print('LOSS: ', loss)
print("Train ACCURACY: ", accuracy)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9925 - loss: 0.0299
# LOSS:  0.03676782175898552
# Train ACCURACY:  0.9911894202232361

# %%
model.save('FNN_model.keras')
