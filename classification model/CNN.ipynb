# %%
import pandas as pd
from tensorflow import keras
from sklearn.model_selection import train_test_split
from data import BodyPart
import tensorflow as tf

# %%
def load_csv(csv_path):
    df = pd.read_csv(csv_path)
    df.drop(['filename'],axis=1, inplace=True)
    classes = df.pop('class_name').unique()
    y = df.pop('class_no')
    
    X = df.astype('float64')
    y = keras.utils.to_categorical(y)
    
    return X, y, classes

# %%
def preprocess_data(X_train):
    processed_X_train = []
    for i in range(X_train.shape[0]):
        embedding = landmarks_to_embedding(tf.reshape(tf.convert_to_tensor(X_train.iloc[i]), (1, 51)))
        processed_X_train.append(tf.reshape(embedding, (34)))
    return tf.convert_to_tensor(processed_X_train)

# %%
def landmarks_to_embedding(landmarks_and_scores):
    """Converts the input landmarks into a pose embedding."""
    # Reshape the flat input into a matrix with shape=(17, 3)
    reshaped_inputs = keras.layers.Reshape((17, 3))(landmarks_and_scores)

    # Normalize landmarks 2D
    landmarks = normalize_pose_landmarks(reshaped_inputs[:, :, :2])
    # Flatten the normalized landmark coordinates into a vector
    embedding = keras.layers.Flatten()(landmarks)
    return embedding

# %%
def normalize_pose_landmarks(landmarks):
    """Normalizes the landmarks translation by moving the pose center to (0,0) and
    scaling it to a constant pose size.
  """
  # Move landmarks so that the pose center becomes (0,0)
    pose_center = get_center_point(landmarks, BodyPart.LEFT_HIP, 
                                 BodyPart.RIGHT_HIP)

    pose_center = tf.expand_dims(pose_center, axis=1)
    # Broadcast the pose center to the same size as the landmark vector to perform
    # substraction
    pose_center = tf.broadcast_to(pose_center, 
                                [tf.size(landmarks) // (17*2), 17, 2])
    landmarks = landmarks - pose_center

    # Scale the landmarks to a constant pose size
    pose_size = get_pose_size(landmarks)
    landmarks /= pose_size
    return landmarks

# %%
def get_center_point(landmarks, left_bodypart, right_bodypart):
    """Calculates the center point of the two given landmarks."""
    left = tf.gather(landmarks, left_bodypart.value, axis=1)
    right = tf.gather(landmarks, right_bodypart.value, axis=1)
    center = left * 0.5 + right * 0.5
    return center

# %%
def get_pose_size(landmarks, torso_size_multiplier=2.5):
    """Calculates pose size.

    It is the maximum of two values:
    * Torso size multiplied by `torso_size_multiplier`
    * Maximum distance from pose center to any pose landmark
    """
    # Hips center
    hips_center = get_center_point(landmarks, BodyPart.LEFT_HIP, 
                                 BodyPart.RIGHT_HIP)

    # Shoulders center
    shoulders_center = get_center_point(landmarks, BodyPart.LEFT_SHOULDER,
                                      BodyPart.RIGHT_SHOULDER)

    # Torso size as the minimum body size
    torso_size = tf.linalg.norm(shoulders_center - hips_center)
    # Pose center
    pose_center_new = get_center_point(landmarks, BodyPart.LEFT_HIP, 
                                     BodyPart.RIGHT_HIP)
    pose_center_new = tf.expand_dims(pose_center_new, axis=1)
    # Broadcast the pose center to the same size as the landmark vector to
    # perform substraction
    pose_center_new = tf.broadcast_to(pose_center_new,
                                    [tf.size(landmarks) // (17*2), 17, 2])

    # Dist to pose center
    d = tf.gather(landmarks - pose_center_new, 0, axis=0,
                name="dist_to_pose_center")
    # Max dist to pose center
    max_dist = tf.reduce_max(tf.linalg.norm(d, axis=0))

    # Normalize scale
    pose_size = tf.maximum(torso_size * torso_size_multiplier, max_dist)
    return pose_size

# %%
def cnn_model(input_shape, num_classes):
    model = keras.Sequential([
        keras.layers.Conv1D(64, 3, activation='relu', input_shape=input_shape),
        keras.layers.MaxPooling1D(2),
        keras.layers.Conv1D(128, 3, activation='relu'),
        keras.layers.MaxPooling1D(2),
        keras.layers.Flatten(),
        keras.layers.Dense(128, activation='relu'),
        keras.layers.Dropout(0.5),
        keras.layers.Dense(num_classes, activation='softmax')
    ])
    return model

# %%
X, y, class_names = load_csv('train_data.csv')
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.15)
X_test, y_test, _ = load_csv('test_data.csv')

# %%
processed_X_train = preprocess_data(X_train)
processed_X_val =  preprocess_data(X_val)
processed_X_test = preprocess_data(X_test)

# %%
# Reshape data for CNN
processed_X_train = tf.expand_dims(processed_X_train, axis=-1)
processed_X_val = tf.expand_dims(processed_X_val, axis=-1)
processed_X_test = tf.expand_dims(processed_X_test, axis=-1)

# %%
input_shape = processed_X_train.shape[1:]

# %%
model = cnn_model(input_shape, len(class_names))
# Out:
# C:\Users\Ugyen Dendup\AppData\Roaming\Python\Python310\site-packages\keras\src\layers\convolutional\base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(processed_X_train, y_train,
                    epochs=200,
                    batch_size=16,
                    validation_data=(processed_X_val, y_val))
# Out:
# Epoch 1/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.3823 - loss: 1.6853 - val_accuracy: 0.6828 - val_loss: 0.9805
# Epoch 2/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6658 - loss: 0.9659 - val_accuracy: 0.7269 - val_loss: 0.6377
# Epoch 3/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7593 - loss: 0.6743 - val_accuracy: 0.8590 - val_loss: 0.3696
# Epoch 4/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8571 - loss: 0.3994 - val_accuracy: 0.9471 - val_loss: 0.1897
# Epoch 5/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9269 - loss: 0.2549 - val_accuracy: 0.9736 - val_loss: 0.1371
# Epoch 6/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9368 - loss: 0.1988 - val_accuracy: 0.9692 - val_loss: 0.0882
# Epoch 7/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9580 - loss: 0.1405 - val_accuracy: 0.9736 - val_loss: 0.0716
# Epoch 8/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9678 - loss: 0.0996 - val_accuracy: 0.9912 - val_loss: 0.0479
# Epoch 9/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9748 - loss: 0.0817 - val_accuracy: 0.9824 - val_loss: 0.0534
# Epoch 10/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9721 - loss: 0.0845 - val_accuracy: 0.9780 - val_loss: 0.0601
# Epoch 11/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9754 - loss: 0.0807 - val_accuracy: 0.9868 - val_loss: 0.0385
# Epoch 12/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9808 - loss: 0.0627 - val_accuracy: 1.0000 - val_loss: 0.0214
# Epoch 13/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9842 - loss: 0.0540 - val_accuracy: 0.9868 - val_loss: 0.0310
# Epoch 14/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9876 - loss: 0.0411 - val_accuracy: 0.9912 - val_loss: 0.0283
# Epoch 15/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9902 - loss: 0.0370 - val_accuracy: 0.9956 - val_loss: 0.0169
# Epoch 16/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9895 - loss: 0.0514 - val_accuracy: 1.0000 - val_loss: 0.0079
# Epoch 17/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9842 - loss: 0.0441 - val_accuracy: 1.0000 - val_loss: 0.0107
# Epoch 18/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9930 - loss: 0.0317 - val_accuracy: 1.0000 - val_loss: 0.0091
# Epoch 19/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9913 - loss: 0.0275 - val_accuracy: 0.9956 - val_loss: 0.0108
# Epoch 20/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9877 - loss: 0.0426 - val_accuracy: 1.0000 - val_loss: 0.0126
# Epoch 21/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9954 - loss: 0.0253 - val_accuracy: 1.0000 - val_loss: 0.0118
# Epoch 22/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9926 - loss: 0.0263 - val_accuracy: 0.9956 - val_loss: 0.0137
# Epoch 23/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9961 - loss: 0.0168 - val_accuracy: 0.9780 - val_loss: 0.0497
# Epoch 24/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9883 - loss: 0.0316 - val_accuracy: 0.9912 - val_loss: 0.0132
# Epoch 25/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9938 - loss: 0.0207 - val_accuracy: 0.9868 - val_loss: 0.0306
# Epoch 26/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9901 - loss: 0.0362 - val_accuracy: 1.0000 - val_loss: 0.0072
# Epoch 27/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9951 - loss: 0.0238 - val_accuracy: 1.0000 - val_loss: 0.0068
# Epoch 28/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9990 - loss: 0.0165 - val_accuracy: 1.0000 - val_loss: 0.0057
# Epoch 29/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9950 - loss: 0.0160 - val_accuracy: 0.9868 - val_loss: 0.0354
# Epoch 30/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9968 - loss: 0.0154 - val_accuracy: 0.9912 - val_loss: 0.0153
# Epoch 31/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9935 - loss: 0.0198 - val_accuracy: 0.9956 - val_loss: 0.0062
# Epoch 32/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9958 - loss: 0.0145 - val_accuracy: 1.0000 - val_loss: 0.0043
# Epoch 33/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9952 - loss: 0.0215 - val_accuracy: 0.9956 - val_loss: 0.0082
# Epoch 34/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9970 - loss: 0.0084 - val_accuracy: 1.0000 - val_loss: 0.0045
# Epoch 35/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9974 - loss: 0.0118 - val_accuracy: 0.9956 - val_loss: 0.0102
# Epoch 36/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9976 - loss: 0.0123 - val_accuracy: 0.9868 - val_loss: 0.0466
# Epoch 37/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9951 - loss: 0.0131 - val_accuracy: 1.0000 - val_loss: 0.0038
# Epoch 38/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9980 - loss: 0.0097 - val_accuracy: 1.0000 - val_loss: 0.0041
# Epoch 39/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9992 - loss: 0.0096 - val_accuracy: 1.0000 - val_loss: 0.0030
# Epoch 40/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9941 - loss: 0.0164 - val_accuracy: 0.9956 - val_loss: 0.0099
# Epoch 41/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9971 - loss: 0.0149 - val_accuracy: 0.9956 - val_loss: 0.0083
# Epoch 42/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9970 - loss: 0.0072 - val_accuracy: 1.0000 - val_loss: 0.0056
# Epoch 43/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9907 - loss: 0.0404 - val_accuracy: 0.9956 - val_loss: 0.0098
# Epoch 44/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9971 - loss: 0.0198 - val_accuracy: 1.0000 - val_loss: 0.0048
# Epoch 45/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9940 - loss: 0.0104 - val_accuracy: 1.0000 - val_loss: 0.0028
# Epoch 46/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9990 - loss: 0.0036 - val_accuracy: 1.0000 - val_loss: 0.0025
# Epoch 47/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9999 - loss: 0.0031 - val_accuracy: 1.0000 - val_loss: 0.0033
# Epoch 48/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9937 - loss: 0.0183 - val_accuracy: 0.9956 - val_loss: 0.0053
# Epoch 49/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9998 - loss: 0.0038 - val_accuracy: 0.9956 - val_loss: 0.0141
# Epoch 50/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9992 - loss: 0.0049 - val_accuracy: 1.0000 - val_loss: 0.0019
# Epoch 51/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9950 - loss: 0.0096 - val_accuracy: 0.9956 - val_loss: 0.0050
# Epoch 52/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9971 - loss: 0.0133 - val_accuracy: 0.9956 - val_loss: 0.0228
# Epoch 53/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9995 - loss: 0.0059 - val_accuracy: 0.9956 - val_loss: 0.0055
# Epoch 54/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9970 - loss: 0.0075 - val_accuracy: 0.9956 - val_loss: 0.0207
# Epoch 55/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9949 - loss: 0.0125 - val_accuracy: 1.0000 - val_loss: 0.0044
# Epoch 56/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9973 - loss: 0.0068 - val_accuracy: 0.9956 - val_loss: 0.0066
# Epoch 57/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9957 - loss: 0.0078 - val_accuracy: 1.0000 - val_loss: 0.0021
# Epoch 58/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 1.0000 - val_loss: 0.0034
# Epoch 59/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0058 - val_accuracy: 1.0000 - val_loss: 0.0023
# Epoch 60/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.9956 - val_loss: 0.0048
# Epoch 61/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9992 - loss: 0.0019 - val_accuracy: 1.0000 - val_loss: 0.0013
# Epoch 62/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 1.0000 - val_loss: 0.0019
# Epoch 63/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9967 - loss: 0.0129 - val_accuracy: 0.9780 - val_loss: 0.0776
# Epoch 64/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9951 - loss: 0.0136 - val_accuracy: 1.0000 - val_loss: 0.0031
# Epoch 65/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9970 - loss: 0.0104 - val_accuracy: 1.0000 - val_loss: 0.0059
# Epoch 66/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9872 - loss: 0.0349 - val_accuracy: 0.9956 - val_loss: 0.0074
# Epoch 67/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9954 - loss: 0.0094 - val_accuracy: 1.0000 - val_loss: 0.0038
# Epoch 68/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9993 - loss: 0.0044 - val_accuracy: 1.0000 - val_loss: 0.0021
# Epoch 69/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 1.0000 - val_loss: 0.0016
# Epoch 70/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9970 - loss: 0.0080 - val_accuracy: 1.0000 - val_loss: 0.0013
# Epoch 71/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9999 - loss: 0.0019 - val_accuracy: 0.9956 - val_loss: 0.0037
# Epoch 72/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9962 - loss: 0.0071 - val_accuracy: 1.0000 - val_loss: 0.0015
# Epoch 73/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9948 - loss: 0.0100 - val_accuracy: 1.0000 - val_loss: 0.0016
# Epoch 74/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9953 - loss: 0.0102 - val_accuracy: 1.0000 - val_loss: 9.1639e-04
# Epoch 75/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9990 - loss: 0.0109 - val_accuracy: 1.0000 - val_loss: 0.0015
# Epoch 76/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9990 - loss: 0.0047 - val_accuracy: 0.9956 - val_loss: 0.0074
# Epoch 77/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9957 - loss: 0.0070 - val_accuracy: 0.9956 - val_loss: 0.0078
# Epoch 78/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9996 - loss: 0.0024 - val_accuracy: 1.0000 - val_loss: 0.0022
# Epoch 79/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 1.0000 - val_loss: 0.0021
# Epoch 80/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 1.0000 - val_loss: 2.6371e-04
# Epoch 81/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 1.0000 - val_loss: 0.0023
# Epoch 82/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9998 - loss: 0.0018 - val_accuracy: 1.0000 - val_loss: 7.3456e-04
# Epoch 83/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9984 - loss: 0.0052 - val_accuracy: 1.0000 - val_loss: 2.2859e-04
# Epoch 84/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9982 - loss: 0.0060 - val_accuracy: 1.0000 - val_loss: 0.0017
# Epoch 85/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9979 - loss: 0.0071 - val_accuracy: 0.9956 - val_loss: 0.0253
# Epoch 86/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9922 - loss: 0.0189 - val_accuracy: 1.0000 - val_loss: 0.0018
# Epoch 87/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.9956 - val_loss: 0.0044
# Epoch 88/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 1.0000 - val_loss: 0.0015
# Epoch 89/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 1.0000 - val_loss: 0.0016
# Epoch 90/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.9956 - val_loss: 0.0032
# Epoch 91/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 6.5599e-04 - val_accuracy: 0.9956 - val_loss: 0.0054
# Epoch 92/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 9.2318e-04 - val_accuracy: 1.0000 - val_loss: 0.0010
# Epoch 93/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9982 - loss: 0.0026 - val_accuracy: 1.0000 - val_loss: 0.0021
# Epoch 94/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9993 - loss: 0.0022 - val_accuracy: 1.0000 - val_loss: 0.0026
# Epoch 95/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9988 - loss: 0.0036 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 96/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9986 - loss: 0.0030 - val_accuracy: 0.9956 - val_loss: 0.0155
# Epoch 97/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9982 - loss: 0.0082 - val_accuracy: 1.0000 - val_loss: 7.6999e-04
# Epoch 98/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9996 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 0.0025
# Epoch 99/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9996 - loss: 0.0024 - val_accuracy: 0.9868 - val_loss: 0.0822
# Epoch 100/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9916 - loss: 0.0317 - val_accuracy: 0.9912 - val_loss: 0.0219
# Epoch 101/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9980 - loss: 0.0051 - val_accuracy: 1.0000 - val_loss: 0.0023
# Epoch 102/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9958 - loss: 0.0133 - val_accuracy: 1.0000 - val_loss: 0.0038
# Epoch 103/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9964 - loss: 0.0054 - val_accuracy: 1.0000 - val_loss: 0.0012
# Epoch 104/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9975 - loss: 0.0119 - val_accuracy: 0.9956 - val_loss: 0.0064
# Epoch 105/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9959 - loss: 0.0104 - val_accuracy: 1.0000 - val_loss: 2.5410e-04
# Epoch 106/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9979 - loss: 0.0062 - val_accuracy: 1.0000 - val_loss: 0.0030
# Epoch 107/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9958 - loss: 0.0075 - val_accuracy: 1.0000 - val_loss: 2.0018e-04
# Epoch 108/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9988 - loss: 0.0040 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 109/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 1.0000 - val_loss: 7.1631e-04
# Epoch 110/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 3.3587e-04 - val_accuracy: 1.0000 - val_loss: 0.0016
# Epoch 111/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 6.7181e-04 - val_accuracy: 1.0000 - val_loss: 2.3963e-04
# Epoch 112/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 8.4222e-04 - val_accuracy: 1.0000 - val_loss: 1.4536e-04
# Epoch 113/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9999 - loss: 0.0020 - val_accuracy: 0.9956 - val_loss: 0.0093
# Epoch 114/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.9956 - val_loss: 0.0043
# Epoch 115/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9987 - loss: 0.0036 - val_accuracy: 1.0000 - val_loss: 4.3568e-04
# Epoch 116/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9997 - loss: 0.0032 - val_accuracy: 0.9956 - val_loss: 0.0094
# Epoch 117/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9983 - loss: 0.0056 - val_accuracy: 1.0000 - val_loss: 2.5240e-04
# Epoch 118/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9996 - loss: 0.0032 - val_accuracy: 1.0000 - val_loss: 6.8081e-04
# Epoch 119/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9987 - loss: 0.0017 - val_accuracy: 1.0000 - val_loss: 1.5347e-04
# Epoch 120/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 8.8277e-04 - val_accuracy: 1.0000 - val_loss: 1.0771e-04
# Epoch 121/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 7.4883e-04 - val_accuracy: 1.0000 - val_loss: 1.9822e-04
# Epoch 122/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 3.3967e-04 - val_accuracy: 1.0000 - val_loss: 2.0849e-04
# Epoch 123/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9994 - loss: 0.0022 - val_accuracy: 1.0000 - val_loss: 2.4689e-04
# Epoch 124/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9990 - loss: 0.0026 - val_accuracy: 1.0000 - val_loss: 8.8262e-04
# Epoch 125/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9977 - loss: 0.0056 - val_accuracy: 1.0000 - val_loss: 2.8196e-04
# Epoch 126/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 6.4335e-04 - val_accuracy: 1.0000 - val_loss: 8.5101e-05
# Epoch 127/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 4.6624e-04 - val_accuracy: 1.0000 - val_loss: 3.9422e-04
# Epoch 128/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 1.0000 - val_loss: 1.2141e-04
# Epoch 129/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 1.0000 - val_loss: 5.1571e-04
# Epoch 130/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 3.7027e-04 - val_accuracy: 0.9956 - val_loss: 0.0051
# Epoch 131/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 5.6051e-04 - val_accuracy: 1.0000 - val_loss: 4.2920e-04
# Epoch 132/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 5.6468e-04 - val_accuracy: 1.0000 - val_loss: 4.3888e-04
# Epoch 133/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 2.7491e-04 - val_accuracy: 1.0000 - val_loss: 9.2743e-04
# Epoch 134/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 5.9122e-04 - val_accuracy: 1.0000 - val_loss: 0.0029
# Epoch 135/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.5687e-04 - val_accuracy: 1.0000 - val_loss: 0.0022
# Epoch 136/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 2.5025e-04 - val_accuracy: 1.0000 - val_loss: 7.0224e-04
# Epoch 137/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9952 - loss: 0.0059 - val_accuracy: 1.0000 - val_loss: 2.1664e-04
# Epoch 138/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 6.2241e-04 - val_accuracy: 1.0000 - val_loss: 6.4317e-04
# Epoch 139/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.9085e-04 - val_accuracy: 1.0000 - val_loss: 1.9504e-04
# Epoch 140/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.4865e-04 - val_accuracy: 1.0000 - val_loss: 9.1728e-04
# Epoch 141/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.0639e-04 - val_accuracy: 1.0000 - val_loss: 6.7324e-04
# Epoch 142/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 2.8020e-04 - val_accuracy: 1.0000 - val_loss: 8.3703e-04
# Epoch 143/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.6437e-04 - val_accuracy: 1.0000 - val_loss: 3.8664e-04
# Epoch 144/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 4.4897e-04 - val_accuracy: 1.0000 - val_loss: 1.4459e-04
# Epoch 145/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9973 - loss: 0.0093 - val_accuracy: 0.9868 - val_loss: 0.0242
# Epoch 146/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9931 - loss: 0.0240 - val_accuracy: 0.9956 - val_loss: 0.0053
# Epoch 147/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9968 - loss: 0.0116 - val_accuracy: 1.0000 - val_loss: 0.0036
# Epoch 148/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9992 - loss: 0.0023 - val_accuracy: 1.0000 - val_loss: 7.2026e-04
# Epoch 149/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 9.2671e-04 - val_accuracy: 1.0000 - val_loss: 0.0015
# Epoch 150/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 6.8215e-04 - val_accuracy: 1.0000 - val_loss: 5.5998e-04
# Epoch 151/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9965 - loss: 0.0072 - val_accuracy: 1.0000 - val_loss: 1.3823e-04
# Epoch 152/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.9956 - val_loss: 0.0084
# Epoch 153/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 6.3365e-04 - val_accuracy: 0.9956 - val_loss: 0.0072
# Epoch 154/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 4.1111e-04 - val_accuracy: 0.9956 - val_loss: 0.0077
# Epoch 155/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 4.4556e-04 - val_accuracy: 0.9956 - val_loss: 0.0095
# Epoch 156/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9969 - loss: 0.0044 - val_accuracy: 1.0000 - val_loss: 2.1172e-04
# Epoch 157/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9999 - loss: 0.0016 - val_accuracy: 1.0000 - val_loss: 4.3346e-04
# Epoch 158/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 5.6606e-04 - val_accuracy: 1.0000 - val_loss: 6.1633e-04
# Epoch 159/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9995 - loss: 0.0017 - val_accuracy: 1.0000 - val_loss: 7.9314e-04
# Epoch 160/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9995 - loss: 0.0012 - val_accuracy: 0.9956 - val_loss: 0.0074
# Epoch 161/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 2.7012e-04 - val_accuracy: 0.9956 - val_loss: 0.0081
# Epoch 162/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9989 - loss: 0.0038 - val_accuracy: 0.9956 - val_loss: 0.0070
# Epoch 163/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9996 - loss: 0.0031 - val_accuracy: 0.9956 - val_loss: 0.0068
# Epoch 164/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9965 - loss: 0.0075 - val_accuracy: 0.9956 - val_loss: 0.0072
# Epoch 165/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 9.7700e-04 - val_accuracy: 1.0000 - val_loss: 2.4578e-04
# Epoch 166/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 7.0019e-04 - val_accuracy: 1.0000 - val_loss: 0.0023
# Epoch 167/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 4.8570e-04 - val_accuracy: 1.0000 - val_loss: 0.0023
# Epoch 168/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 3.0166e-04 - val_accuracy: 1.0000 - val_loss: 0.0023
# Epoch 169/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9996 - loss: 0.0012 - val_accuracy: 1.0000 - val_loss: 3.3655e-05
# Epoch 170/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 4.0568e-04 - val_accuracy: 1.0000 - val_loss: 8.4033e-04
# Epoch 171/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9987 - loss: 0.0038 - val_accuracy: 1.0000 - val_loss: 6.4397e-04
# Epoch 172/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9978 - loss: 0.0024 - val_accuracy: 1.0000 - val_loss: 9.8607e-04
# Epoch 173/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 6.8733e-04 - val_accuracy: 1.0000 - val_loss: 0.0012
# Epoch 174/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9999 - loss: 3.1071e-04 - val_accuracy: 1.0000 - val_loss: 0.0023
# Epoch 175/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 2.6320e-04 - val_accuracy: 1.0000 - val_loss: 1.8613e-04
# Epoch 176/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 3.4915e-04 - val_accuracy: 1.0000 - val_loss: 4.3221e-04
# Epoch 177/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 2.7111e-04 - val_accuracy: 1.0000 - val_loss: 1.0569e-04
# Epoch 178/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9997 - loss: 0.0018 - val_accuracy: 1.0000 - val_loss: 0.0028
# Epoch 179/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9986 - loss: 0.0047 - val_accuracy: 1.0000 - val_loss: 0.0013
# Epoch 180/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 4.5542e-04 - val_accuracy: 1.0000 - val_loss: 5.4320e-04
# Epoch 181/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9991 - loss: 0.0027 - val_accuracy: 1.0000 - val_loss: 3.6959e-04
# Epoch 182/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9995 - loss: 0.0012 - val_accuracy: 0.9956 - val_loss: 0.0092
# Epoch 183/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9993 - loss: 0.0020 - val_accuracy: 0.9956 - val_loss: 0.0081
# Epoch 184/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9977 - loss: 0.0097 - val_accuracy: 1.0000 - val_loss: 0.0013
# Epoch 185/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9970 - loss: 0.0089 - val_accuracy: 0.9912 - val_loss: 0.1066
# Epoch 186/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9993 - loss: 0.0028 - val_accuracy: 0.9956 - val_loss: 0.0152
# Epoch 187/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9996 - loss: 0.0023 - val_accuracy: 1.0000 - val_loss: 2.6792e-05
# Epoch 188/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9999 - loss: 4.9876e-04 - val_accuracy: 1.0000 - val_loss: 1.2269e-05
# Epoch 189/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 4.9335e-04 - val_accuracy: 1.0000 - val_loss: 1.8551e-05
# Epoch 190/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 4.4709e-04 - val_accuracy: 1.0000 - val_loss: 3.6431e-05
# Epoch 191/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9999 - loss: 2.4690e-04 - val_accuracy: 1.0000 - val_loss: 6.4931e-05
# Epoch 192/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 6.6682e-04 - val_accuracy: 1.0000 - val_loss: 2.1229e-05
# Epoch 193/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 8.6032e-05 - val_accuracy: 1.0000 - val_loss: 8.5667e-05
# Epoch 194/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9978 - loss: 0.0052 - val_accuracy: 1.0000 - val_loss: 2.1281e-05
# Epoch 195/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9996 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 7.5601e-05
# Epoch 196/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 1.0000 - val_loss: 2.4436e-04
# Epoch 197/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9985 - loss: 0.0123 - val_accuracy: 0.9956 - val_loss: 0.0122
# Epoch 198/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9974 - loss: 0.0125 - val_accuracy: 1.0000 - val_loss: 1.9030e-04
# Epoch 199/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9947 - loss: 0.0141 - val_accuracy: 1.0000 - val_loss: 4.7984e-04
# Epoch 200/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 1.0000 - val_loss: 1.6902e-04

# %%
print('-----------------EVALUATION----------------')
loss, accuracy = model.evaluate(processed_X_test, y_test)
print('LOSS: ', loss)
print("Test ACCURACY: ", accuracy)
# Out:
# -----------------EVALUATION----------------
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9996 - loss: 0.0019
# LOSS:  0.010166078805923462
# Test ACCURACY:  0.9977195262908936

# %%
loss, accuracy = model.evaluate(processed_X_train, y_train)
print('LOSS: ', loss)
print("Train ACCURACY: ", accuracy)
# Out:
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 2.5230e-06
# LOSS:  2.2554600036528427e-06
# Train ACCURACY:  1.0

# %%
loss, accuracy = model.evaluate(processed_X_val, y_val)
print('LOSS: ', loss)
print("Validation ACCURACY: ", accuracy)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 3.3607e-04
# LOSS:  0.00016902180504985154
# Train ACCURACY:  1.0

# %%
model.save('CNN_model.keras')

# %%
pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# Collecting opencv-python
#   Downloading opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl (38.6 MB)
#      ---------------------------------------- 38.6/38.6 MB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17.3 in c:\programdata\anaconda3\lib\site-packages (from opencv-python) (1.23.5)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.9.0.80

# %% [markdown]
# ## Model Prection test

# %%
# Preprocessor for a single image

import tensorflow as tf
import numpy as np
from movenet import Movenet
import os

# Load MoveNet model
movenet = Movenet('movenet_thunder.tflite')

def detect_landmarks(image, detection_threshold=0.1):
    # Detect landmarks in the given image
    person = movenet.detect(image)
    
    # Check if any person is detected
    if person is None:
        return None
    
    # Check if all landmarks are above the detection threshold
    min_landmark_score = min([keypoint.score for keypoint in person.keypoints])
    if min_landmark_score < detection_threshold:
        return None
    
    # Get landmarks and scale them to the same size as the input image
    pose_landmarks = np.array([[keypoint.coordinate.x, keypoint.coordinate.y, keypoint.score] for keypoint in person.keypoints], dtype=np.float32)
    
    return pose_landmarks

def preprocess_image(image_path, target_shape):
    # Read image
    image = tf.io.read_file(image_path)
    image = tf.io.decode_jpeg(image)
    
    # Resize image to target shape
    image = tf.image.resize(image, target_shape)
    
    # Convert image to numpy array
    image = image.numpy()
    
    return image

def process_single_image(image_path, target_shape=(256, 256), detection_threshold=0.1):
    # Preprocess the image
    image = preprocess_image(image_path, target_shape)
    
    # Detect landmarks
    landmarks = detect_landmarks(image, detection_threshold)
    
    if landmarks is not None:
        # Convert landmarks to DataFrame
        list_name = [[bodypart.name + '_x', bodypart.name + '_y', bodypart.name + '_score'] for bodypart in BodyPart]
        
        header_name = []
        for columns_name in list_name:
            header_name += columns_name
        header_name = ['filename'] + header_name
        
        landmarks = landmarks.flatten().astype(str).tolist()
        landmarks = [''] + landmarks  # Empty string for filename
        landmarks_dict = {header_name[i]: [landmarks[i]] for i in range(len(header_name))}
        
        df = pd.DataFrame(landmarks_dict)
        
        return df
    else:
        return None

# %%
image_path = 'dog.jpg'
landmarks = process_single_image(image_path)
if landmarks is not None:
    print("Landmarks detected successfully:", landmarks)
else:
    print("No person detected or landmarks below threshold.")
# Out:
# No person detected or landmarks below threshold.

# %%
landmarks.drop('filename', axis=1, inplace=True)

# %%
landmarks.head()
# Out:
#   NOSE_x NOSE_y NOSE_score LEFT_EYE_x LEFT_EYE_y LEFT_EYE_score RIGHT_EYE_x  \
# 0  124.0  176.0  0.5762694      118.0      181.0      0.5907945       118.0
#
#   RIGHT_EYE_y RIGHT_EYE_score LEFT_EAR_x  ... LEFT_KNEE_score RIGHT_KNEE_x  \
# 0       180.0       0.5118377      104.0  ...        0.898908        181.0
#
#   RIGHT_KNEE_y RIGHT_KNEE_score LEFT_ANKLE_x LEFT_ANKLE_y LEFT_ANKLE_score  \
# 0        145.0       0.81275725        216.0        207.0        0.8582211
#
#   RIGHT_ANKLE_x RIGHT_ANKLE_y RIGHT_ANKLE_score
# 0         216.0         207.0         0.6017157
#
# [1 rows x 51 columns]

# %%
landmarks = landmarks.astype(float)

# %%
X.shape
# Out:
# (1512, 51)

# %%
test = preprocess_data(landmarks)

# %%
arr = model.predict(test)
arr
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# array([[5.3986796e-13, 6.9385823e-19, 1.0000000e+00, 3.0035122e-20,
#         1.6094400e-17, 2.4252008e-14, 4.9101904e-22, 1.6396834e-11]],
#       dtype=float32)

# %%
arr_flat = arr.flatten()

# Find the index of the maximum element
max_index = np.argmax(arr_flat)

# Get the value of the maximum element
max_value = arr_flat[max_index]

print("Index of the highest element:", max_index)
          
print("Value of the highest element:", max_value)
# Out:
# Index of the highest element: 2
# Value of the highest element: 1.0

# %%
# 0 = chair
# 1 = cobra
# 2 = dog
# 3 = no_pose
# 4 = shoulder_stand
# 5 = triangle
# 6 = tree
# 7 - warrior
