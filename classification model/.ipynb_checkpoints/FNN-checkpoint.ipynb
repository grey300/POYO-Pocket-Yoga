# %%
import pandas as pd
from tensorflow import keras
from sklearn.model_selection import train_test_split
from data import BodyPart
import tensorflow as tf

# %%
pip show tensorflow_decision_forests
# Out:
# Name: tensorflow-decision-forests
# Version: 1.8.1
# Summary: Collection of training and inference decision forest algorithms.
# Home-page: https://github.com/tensorflow/decision-forests
# Author: Google Inc.
# Author-email: packages@tensorflow.org
# License: Apache 2.0
# Location: c:\users\dell\appdata\roaming\python\python310\site-packages
# Requires: absl-py, numpy, pandas, six, tensorflow, wheel, wurlitzer
# Required-by: tensorflowjs
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution - (c:\users\dell\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\dell\appdata\roaming\python\python310\site-packages)

# %%
def load_csv(csv_path):
    df = pd.read_csv(csv_path)
    df.drop(['filename'],axis=1, inplace=True)
    classes = df.pop('class_name').unique()
    y = df.pop('class_no')
    
    X = df.astype('float64')
    y = keras.utils.to_categorical(y)
    
    return X, y, classes

# %%
def get_center_point(landmarks, left_bodypart, right_bodypart):
    """Calculates the center point of the two given landmarks."""
    left = tf.gather(landmarks, left_bodypart.value, axis=1)
    right = tf.gather(landmarks, right_bodypart.value, axis=1)
    center = left * 0.5 + right * 0.5
    return center

# %%
def get_pose_size(landmarks, torso_size_multiplier=2.5):
    """Calculates pose size.

    It is the maximum of two values:
    * Torso size multiplied by `torso_size_multiplier`
    * Maximum distance from pose center to any pose landmark
    """
    # Hips center
    hips_center = get_center_point(landmarks, BodyPart.LEFT_HIP, 
                                 BodyPart.RIGHT_HIP)

    # Shoulders center
    shoulders_center = get_center_point(landmarks, BodyPart.LEFT_SHOULDER,
                                      BodyPart.RIGHT_SHOULDER)

    # Torso size as the minimum body size
    torso_size = tf.linalg.norm(shoulders_center - hips_center)
    # Pose center
    pose_center_new = get_center_point(landmarks, BodyPart.LEFT_HIP, 
                                     BodyPart.RIGHT_HIP)
    pose_center_new = tf.expand_dims(pose_center_new, axis=1)
    # Broadcast the pose center to the same size as the landmark vector to
    # perform substraction
    pose_center_new = tf.broadcast_to(pose_center_new,
                                    [tf.size(landmarks) // (17*2), 17, 2])

    # Dist to pose center
    d = tf.gather(landmarks - pose_center_new, 0, axis=0,
                name="dist_to_pose_center")
    # Max dist to pose center
    max_dist = tf.reduce_max(tf.linalg.norm(d, axis=0))

    # Normalize scale
    pose_size = tf.maximum(torso_size * torso_size_multiplier, max_dist)
    return pose_size

# %%
def normalize_pose_landmarks(landmarks):
    """Normalizes the landmarks translation by moving the pose center to (0,0) and
    scaling it to a constant pose size.
  """
  # Move landmarks so that the pose center becomes (0,0)
    pose_center = get_center_point(landmarks, BodyPart.LEFT_HIP, 
                                 BodyPart.RIGHT_HIP)

    pose_center = tf.expand_dims(pose_center, axis=1)
    # Broadcast the pose center to the same size as the landmark vector to perform
    # substraction
    pose_center = tf.broadcast_to(pose_center, 
                                [tf.size(landmarks) // (17*2), 17, 2])
    landmarks = landmarks - pose_center

    # Scale the landmarks to a constant pose size
    pose_size = get_pose_size(landmarks)
    landmarks /= pose_size
    return landmarks

# %%
def landmarks_to_embedding(landmarks_and_scores):
    """Converts the input landmarks into a pose embedding."""
    # Reshape the flat input into a matrix with shape=(17, 3)
    reshaped_inputs = keras.layers.Reshape((17, 3))(landmarks_and_scores)

    # Normalize landmarks 2D
    landmarks = normalize_pose_landmarks(reshaped_inputs[:, :, :2])
    # Flatten the normalized landmark coordinates into a vector
    embedding = keras.layers.Flatten()(landmarks)
    return embedding

# %%
def preprocess_data(X_train):
    processed_X_train = []
    for i in range(X_train.shape[0]):
        embedding = landmarks_to_embedding(tf.reshape(tf.convert_to_tensor(X_train.iloc[i]), (1, 51)))
        processed_X_train.append(tf.reshape(embedding, (34)))
    return tf.convert_to_tensor(processed_X_train)

# %%
X, y, class_names = load_csv('train_data.csv')
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.15)
X_test, y_test, _ = load_csv('test_data.csv')

# %%
processed_X_train = preprocess_data(X_train)
processed_X_val =  preprocess_data(X_val)
processed_X_test = preprocess_data(X_test)
# Out:
# WARNING:tensorflow:From C:\Users\Dell\AppData\Roaming\Python\Python310\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
inputs = tf.keras.Input(shape=(34, ))
layer = keras.layers.Dense(128, activation=tf.nn.relu6)(inputs)
layer = keras.layers.Dropout(0.5)(layer)
layer = keras.layers.Dense(64, activation=tf.nn.relu6)(layer)
layer = keras.layers.Dropout(0.5)(layer)
outputs = keras.layers.Dense(len(class_names), activation="softmax")(layer)

# %%
model = keras.Model(inputs, outputs)

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
# Out:
# WARNING:tensorflow:From C:\Users\Dell\AppData\Roaming\Python\Python310\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
# checkpoint_path = "weights.best.hdf5"
# checkpoint = keras.callbacks.ModelCheckpoint(checkpoint_path,
#                              monitor='val_accuracy',
#                              verbose=1,
#                              save_best_only=True,
#                              mode='max')
# earlystopping = keras.callbacks.EarlyStopping(monitor='val_accuracy', 
#                                        patience=20)

# %%
history = model.fit(processed_X_train, y_train,
                    epochs=200,
                    batch_size=16,
                    validation_data=(processed_X_val, y_val))
# Out:
# Epoch 1/200
# WARNING:tensorflow:From C:\Users\Dell\AppData\Roaming\Python\Python310\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\Dell\AppData\Roaming\Python\Python310\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 81/81 [==============================] - 1s 4ms/step - loss: 1.6385 - accuracy: 0.4062 - val_loss: 1.1640 - val_accuracy: 0.5683
# Epoch 2/200
# 81/81 [==============================] - 0s 2ms/step - loss: 1.1365 - accuracy: 0.5471 - val_loss: 0.8373 - val_accuracy: 0.7269
# Epoch 3/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.9337 - accuracy: 0.6358 - val_loss: 0.6794 - val_accuracy: 0.7621
# Epoch 4/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.7907 - accuracy: 0.6864 - val_loss: 0.5508 - val_accuracy: 0.8546
# Epoch 5/200
# 81/81 [==============================] - 0s 3ms/step - loss: 0.7022 - accuracy: 0.7346 - val_loss: 0.4522 - val_accuracy: 0.8811
# Epoch 6/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.6088 - accuracy: 0.7837 - val_loss: 0.3890 - val_accuracy: 0.8767
# Epoch 7/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.5209 - accuracy: 0.8202 - val_loss: 0.3263 - val_accuracy: 0.9427
# Epoch 8/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.5011 - accuracy: 0.8179 - val_loss: 0.2977 - val_accuracy: 0.9207
# Epoch 9/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4307 - accuracy: 0.8576 - val_loss: 0.2672 - val_accuracy: 0.9339
# Epoch 10/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4148 - accuracy: 0.8482 - val_loss: 0.2348 - val_accuracy: 0.9427
# Epoch 11/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.3930 - accuracy: 0.8677 - val_loss: 0.2202 - val_accuracy: 0.9339
# Epoch 12/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.3589 - accuracy: 0.8833 - val_loss: 0.2021 - val_accuracy: 0.9427
# Epoch 13/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.3206 - accuracy: 0.8973 - val_loss: 0.1903 - val_accuracy: 0.9427
# Epoch 14/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.3363 - accuracy: 0.8817 - val_loss: 0.1752 - val_accuracy: 0.9559
# Epoch 15/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.2860 - accuracy: 0.9089 - val_loss: 0.1694 - val_accuracy: 0.9648
# Epoch 16/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.3071 - accuracy: 0.8981 - val_loss: 0.1620 - val_accuracy: 0.9604
# Epoch 17/200
# 81/81 [==============================] - 0s 3ms/step - loss: 0.2635 - accuracy: 0.9175 - val_loss: 0.1522 - val_accuracy: 0.9736
# Epoch 18/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.2591 - accuracy: 0.9152 - val_loss: 0.1415 - val_accuracy: 0.9736
# Epoch 19/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.2482 - accuracy: 0.9167 - val_loss: 0.1342 - val_accuracy: 0.9736
# Epoch 20/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.2320 - accuracy: 0.9276 - val_loss: 0.1240 - val_accuracy: 0.9736
# Epoch 21/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.2354 - accuracy: 0.9183 - val_loss: 0.1207 - val_accuracy: 0.9780
# Epoch 22/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.2156 - accuracy: 0.9315 - val_loss: 0.1276 - val_accuracy: 0.9692
# Epoch 23/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.2148 - accuracy: 0.9268 - val_loss: 0.1063 - val_accuracy: 0.9824
# Epoch 24/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1867 - accuracy: 0.9471 - val_loss: 0.1096 - val_accuracy: 0.9780
# Epoch 25/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1725 - accuracy: 0.9440 - val_loss: 0.1157 - val_accuracy: 0.9736
# Epoch 26/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1851 - accuracy: 0.9494 - val_loss: 0.1033 - val_accuracy: 0.9780
# Epoch 27/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.2036 - accuracy: 0.9393 - val_loss: 0.0989 - val_accuracy: 0.9868
# Epoch 28/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1857 - accuracy: 0.9471 - val_loss: 0.0928 - val_accuracy: 0.9824
# Epoch 29/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1504 - accuracy: 0.9494 - val_loss: 0.0962 - val_accuracy: 0.9824
# Epoch 30/200
# 81/81 [==============================] - 0s 3ms/step - loss: 0.1605 - accuracy: 0.9525 - val_loss: 0.0940 - val_accuracy: 0.9780
# Epoch 31/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1523 - accuracy: 0.9588 - val_loss: 0.0911 - val_accuracy: 0.9824
# Epoch 32/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1539 - accuracy: 0.9502 - val_loss: 0.0938 - val_accuracy: 0.9780
# Epoch 33/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1525 - accuracy: 0.9486 - val_loss: 0.0914 - val_accuracy: 0.9780
# Epoch 34/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1355 - accuracy: 0.9556 - val_loss: 0.0859 - val_accuracy: 0.9868
# Epoch 35/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1450 - accuracy: 0.9479 - val_loss: 0.0882 - val_accuracy: 0.9824
# Epoch 36/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1374 - accuracy: 0.9619 - val_loss: 0.0899 - val_accuracy: 0.9868
# Epoch 37/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1328 - accuracy: 0.9603 - val_loss: 0.0824 - val_accuracy: 0.9868
# Epoch 38/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1359 - accuracy: 0.9588 - val_loss: 0.0792 - val_accuracy: 0.9824
# Epoch 39/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1233 - accuracy: 0.9564 - val_loss: 0.0708 - val_accuracy: 0.9868
# Epoch 40/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0971 - accuracy: 0.9728 - val_loss: 0.0756 - val_accuracy: 0.9780
# Epoch 41/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1112 - accuracy: 0.9619 - val_loss: 0.0761 - val_accuracy: 0.9824
# Epoch 42/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1049 - accuracy: 0.9704 - val_loss: 0.0715 - val_accuracy: 0.9824
# Epoch 43/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1100 - accuracy: 0.9650 - val_loss: 0.0697 - val_accuracy: 0.9868
# Epoch 44/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1086 - accuracy: 0.9650 - val_loss: 0.0778 - val_accuracy: 0.9868
# Epoch 45/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0936 - accuracy: 0.9689 - val_loss: 0.0736 - val_accuracy: 0.9868
# Epoch 46/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0963 - accuracy: 0.9720 - val_loss: 0.0661 - val_accuracy: 0.9912
# Epoch 47/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0925 - accuracy: 0.9712 - val_loss: 0.0753 - val_accuracy: 0.9912
# Epoch 48/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.1022 - accuracy: 0.9689 - val_loss: 0.0783 - val_accuracy: 0.9868
# Epoch 49/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0988 - accuracy: 0.9696 - val_loss: 0.0721 - val_accuracy: 0.9912
# Epoch 50/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0937 - accuracy: 0.9720 - val_loss: 0.0702 - val_accuracy: 0.9868
# Epoch 51/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0863 - accuracy: 0.9696 - val_loss: 0.0547 - val_accuracy: 0.9912
# Epoch 52/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0760 - accuracy: 0.9767 - val_loss: 0.0644 - val_accuracy: 0.9912
# Epoch 53/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0915 - accuracy: 0.9712 - val_loss: 0.0607 - val_accuracy: 0.9868
# Epoch 54/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0826 - accuracy: 0.9774 - val_loss: 0.0588 - val_accuracy: 0.9912
# Epoch 55/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0745 - accuracy: 0.9751 - val_loss: 0.0626 - val_accuracy: 0.9912
# Epoch 56/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0826 - accuracy: 0.9743 - val_loss: 0.0579 - val_accuracy: 0.9912
# Epoch 57/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0694 - accuracy: 0.9813 - val_loss: 0.0601 - val_accuracy: 0.9912
# Epoch 58/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0704 - accuracy: 0.9774 - val_loss: 0.0589 - val_accuracy: 0.9912
# Epoch 59/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0806 - accuracy: 0.9743 - val_loss: 0.0517 - val_accuracy: 0.9912
# Epoch 60/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0670 - accuracy: 0.9798 - val_loss: 0.0558 - val_accuracy: 0.9912
# Epoch 61/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0730 - accuracy: 0.9759 - val_loss: 0.0676 - val_accuracy: 0.9912
# Epoch 62/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0856 - accuracy: 0.9712 - val_loss: 0.0501 - val_accuracy: 0.9956
# Epoch 63/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0720 - accuracy: 0.9782 - val_loss: 0.0607 - val_accuracy: 0.9868
# Epoch 64/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0858 - accuracy: 0.9767 - val_loss: 0.0631 - val_accuracy: 0.9912
# Epoch 65/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0717 - accuracy: 0.9759 - val_loss: 0.0533 - val_accuracy: 0.9868
# Epoch 66/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0696 - accuracy: 0.9751 - val_loss: 0.0560 - val_accuracy: 0.9868
# Epoch 67/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0759 - accuracy: 0.9743 - val_loss: 0.0622 - val_accuracy: 0.9868
# Epoch 68/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0583 - accuracy: 0.9852 - val_loss: 0.0511 - val_accuracy: 0.9956
# Epoch 69/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0533 - accuracy: 0.9805 - val_loss: 0.0582 - val_accuracy: 0.9912
# Epoch 70/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0784 - accuracy: 0.9743 - val_loss: 0.0613 - val_accuracy: 0.9912
# Epoch 71/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0623 - accuracy: 0.9782 - val_loss: 0.0594 - val_accuracy: 0.9912
# Epoch 72/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0493 - accuracy: 0.9891 - val_loss: 0.0604 - val_accuracy: 0.9912
# Epoch 73/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0482 - accuracy: 0.9844 - val_loss: 0.0644 - val_accuracy: 0.9912
# Epoch 74/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0609 - accuracy: 0.9829 - val_loss: 0.0573 - val_accuracy: 0.9868
# Epoch 75/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0588 - accuracy: 0.9821 - val_loss: 0.0579 - val_accuracy: 0.9912
# Epoch 76/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0487 - accuracy: 0.9891 - val_loss: 0.0610 - val_accuracy: 0.9912
# Epoch 77/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0515 - accuracy: 0.9829 - val_loss: 0.0575 - val_accuracy: 0.9912
# Epoch 78/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0452 - accuracy: 0.9837 - val_loss: 0.0622 - val_accuracy: 0.9912
# Epoch 79/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0498 - accuracy: 0.9852 - val_loss: 0.0617 - val_accuracy: 0.9912
# Epoch 80/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0427 - accuracy: 0.9868 - val_loss: 0.0610 - val_accuracy: 0.9912
# Epoch 81/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0475 - accuracy: 0.9837 - val_loss: 0.0672 - val_accuracy: 0.9912
# Epoch 82/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0503 - accuracy: 0.9837 - val_loss: 0.0671 - val_accuracy: 0.9912
# Epoch 83/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0577 - accuracy: 0.9821 - val_loss: 0.0595 - val_accuracy: 0.9912
# Epoch 84/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0395 - accuracy: 0.9844 - val_loss: 0.0693 - val_accuracy: 0.9912
# Epoch 85/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0430 - accuracy: 0.9875 - val_loss: 0.0655 - val_accuracy: 0.9912
# Epoch 86/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0526 - accuracy: 0.9829 - val_loss: 0.0605 - val_accuracy: 0.9912
# Epoch 87/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0496 - accuracy: 0.9837 - val_loss: 0.0571 - val_accuracy: 0.9956
# Epoch 88/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0388 - accuracy: 0.9891 - val_loss: 0.0574 - val_accuracy: 0.9912
# Epoch 89/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0434 - accuracy: 0.9875 - val_loss: 0.0628 - val_accuracy: 0.9912
# Epoch 90/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0554 - accuracy: 0.9860 - val_loss: 0.0622 - val_accuracy: 0.9912
# Epoch 91/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0445 - accuracy: 0.9868 - val_loss: 0.0602 - val_accuracy: 0.9912
# Epoch 92/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0436 - accuracy: 0.9860 - val_loss: 0.0739 - val_accuracy: 0.9912
# Epoch 93/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0434 - accuracy: 0.9860 - val_loss: 0.0645 - val_accuracy: 0.9912
# Epoch 94/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0435 - accuracy: 0.9868 - val_loss: 0.0631 - val_accuracy: 0.9912
# Epoch 95/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0397 - accuracy: 0.9852 - val_loss: 0.0576 - val_accuracy: 0.9956
# Epoch 96/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0286 - accuracy: 0.9930 - val_loss: 0.0602 - val_accuracy: 0.9912
# Epoch 97/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0302 - accuracy: 0.9930 - val_loss: 0.0623 - val_accuracy: 0.9912
# Epoch 98/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0457 - accuracy: 0.9837 - val_loss: 0.0553 - val_accuracy: 0.9868
# Epoch 99/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0340 - accuracy: 0.9907 - val_loss: 0.0554 - val_accuracy: 0.9956
# Epoch 100/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0376 - accuracy: 0.9891 - val_loss: 0.0659 - val_accuracy: 0.9912
# Epoch 101/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0302 - accuracy: 0.9930 - val_loss: 0.0585 - val_accuracy: 0.9912
# Epoch 102/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0298 - accuracy: 0.9914 - val_loss: 0.0590 - val_accuracy: 0.9912
# Epoch 103/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0382 - accuracy: 0.9860 - val_loss: 0.0489 - val_accuracy: 0.9956
# Epoch 104/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0302 - accuracy: 0.9930 - val_loss: 0.0545 - val_accuracy: 0.9912
# Epoch 105/200
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0298 - accuracy: 0.9899 - val_loss: 0.0473 - val_accuracy: 0.9956
# Epoch 106/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0332 - accuracy: 0.9907 - val_loss: 0.0680 - val_accuracy: 0.9912
# Epoch 107/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0356 - accuracy: 0.9891 - val_loss: 0.0621 - val_accuracy: 0.9912
# Epoch 108/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0367 - accuracy: 0.9891 - val_loss: 0.0520 - val_accuracy: 0.9912
# Epoch 109/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0279 - accuracy: 0.9891 - val_loss: 0.0442 - val_accuracy: 0.9912
# Epoch 110/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0393 - accuracy: 0.9860 - val_loss: 0.0486 - val_accuracy: 0.9868
# Epoch 111/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0311 - accuracy: 0.9891 - val_loss: 0.0566 - val_accuracy: 0.9868
# Epoch 112/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0363 - accuracy: 0.9837 - val_loss: 0.0539 - val_accuracy: 0.9868
# Epoch 113/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0334 - accuracy: 0.9930 - val_loss: 0.0462 - val_accuracy: 0.9956
# Epoch 114/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0304 - accuracy: 0.9899 - val_loss: 0.0504 - val_accuracy: 0.9912
# Epoch 115/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0322 - accuracy: 0.9899 - val_loss: 0.0556 - val_accuracy: 0.9912
# Epoch 116/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0361 - accuracy: 0.9875 - val_loss: 0.0574 - val_accuracy: 0.9912
# Epoch 117/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0414 - accuracy: 0.9875 - val_loss: 0.0472 - val_accuracy: 0.9868
# Epoch 118/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0282 - accuracy: 0.9907 - val_loss: 0.0436 - val_accuracy: 0.9912
# Epoch 119/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0178 - accuracy: 0.9953 - val_loss: 0.0601 - val_accuracy: 0.9912
# Epoch 120/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0319 - accuracy: 0.9914 - val_loss: 0.0615 - val_accuracy: 0.9868
# Epoch 121/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0269 - accuracy: 0.9930 - val_loss: 0.0708 - val_accuracy: 0.9912
# Epoch 122/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0302 - accuracy: 0.9899 - val_loss: 0.0586 - val_accuracy: 0.9912
# Epoch 123/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0333 - accuracy: 0.9883 - val_loss: 0.0682 - val_accuracy: 0.9912
# Epoch 124/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0371 - accuracy: 0.9875 - val_loss: 0.0608 - val_accuracy: 0.9912
# Epoch 125/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0311 - accuracy: 0.9899 - val_loss: 0.0476 - val_accuracy: 0.9956
# Epoch 126/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0330 - accuracy: 0.9914 - val_loss: 0.0564 - val_accuracy: 0.9912
# Epoch 127/200
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0309 - accuracy: 0.9899 - val_loss: 0.0570 - val_accuracy: 0.9912
# Epoch 128/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0220 - accuracy: 0.9953 - val_loss: 0.0668 - val_accuracy: 0.9912
# Epoch 129/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0530 - accuracy: 0.9860 - val_loss: 0.0567 - val_accuracy: 0.9868
# Epoch 130/200
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0331 - accuracy: 0.9891 - val_loss: 0.0565 - val_accuracy: 0.9912
# Epoch 131/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0289 - accuracy: 0.9899 - val_loss: 0.0578 - val_accuracy: 0.9868
# Epoch 132/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0247 - accuracy: 0.9914 - val_loss: 0.0501 - val_accuracy: 0.9912
# Epoch 133/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0350 - accuracy: 0.9907 - val_loss: 0.0501 - val_accuracy: 0.9912
# Epoch 134/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0237 - accuracy: 0.9907 - val_loss: 0.0498 - val_accuracy: 0.9956
# Epoch 135/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0312 - accuracy: 0.9875 - val_loss: 0.0675 - val_accuracy: 0.9868
# Epoch 136/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0270 - accuracy: 0.9938 - val_loss: 0.0494 - val_accuracy: 0.9912
# Epoch 137/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0281 - accuracy: 0.9938 - val_loss: 0.0460 - val_accuracy: 0.9956
# Epoch 138/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0299 - accuracy: 0.9907 - val_loss: 0.0446 - val_accuracy: 0.9956
# Epoch 139/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0203 - accuracy: 0.9938 - val_loss: 0.0489 - val_accuracy: 0.9956
# Epoch 140/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0188 - accuracy: 0.9946 - val_loss: 0.0547 - val_accuracy: 0.9912
# Epoch 141/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0272 - accuracy: 0.9938 - val_loss: 0.0688 - val_accuracy: 0.9912
# Epoch 142/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0376 - accuracy: 0.9891 - val_loss: 0.0722 - val_accuracy: 0.9868
# Epoch 143/200
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0334 - accuracy: 0.9875 - val_loss: 0.0779 - val_accuracy: 0.9912
# Epoch 144/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0274 - accuracy: 0.9899 - val_loss: 0.0770 - val_accuracy: 0.9912
# Epoch 145/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0248 - accuracy: 0.9930 - val_loss: 0.0581 - val_accuracy: 0.9912
# Epoch 146/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0253 - accuracy: 0.9946 - val_loss: 0.0583 - val_accuracy: 0.9912
# Epoch 147/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0368 - accuracy: 0.9875 - val_loss: 0.0563 - val_accuracy: 0.9912
# Epoch 148/200
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0225 - accuracy: 0.9938 - val_loss: 0.0566 - val_accuracy: 0.9956
# Epoch 149/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0226 - accuracy: 0.9946 - val_loss: 0.0643 - val_accuracy: 0.9912
# Epoch 150/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0166 - accuracy: 0.9946 - val_loss: 0.0709 - val_accuracy: 0.9912
# Epoch 151/200
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0190 - accuracy: 0.9953 - val_loss: 0.0571 - val_accuracy: 0.9912
# Epoch 152/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0262 - accuracy: 0.9899 - val_loss: 0.0510 - val_accuracy: 0.9912
# Epoch 153/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0246 - accuracy: 0.9907 - val_loss: 0.0516 - val_accuracy: 0.9956
# Epoch 154/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0221 - accuracy: 0.9938 - val_loss: 0.0534 - val_accuracy: 0.9912
# Epoch 155/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0208 - accuracy: 0.9914 - val_loss: 0.0555 - val_accuracy: 0.9912
# Epoch 156/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0250 - accuracy: 0.9938 - val_loss: 0.0585 - val_accuracy: 0.9912
# Epoch 157/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0185 - accuracy: 0.9938 - val_loss: 0.0553 - val_accuracy: 0.9912
# Epoch 158/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0245 - accuracy: 0.9938 - val_loss: 0.0494 - val_accuracy: 0.9912
# Epoch 159/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0174 - accuracy: 0.9922 - val_loss: 0.0413 - val_accuracy: 0.9912
# Epoch 160/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0433 - accuracy: 0.9837 - val_loss: 0.0481 - val_accuracy: 0.9912
# Epoch 161/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0209 - accuracy: 0.9953 - val_loss: 0.0472 - val_accuracy: 0.9912
# Epoch 162/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0269 - accuracy: 0.9899 - val_loss: 0.0540 - val_accuracy: 0.9912
# Epoch 163/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0364 - accuracy: 0.9883 - val_loss: 0.0459 - val_accuracy: 0.9912
# Epoch 164/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0289 - accuracy: 0.9899 - val_loss: 0.0446 - val_accuracy: 0.9912
# Epoch 165/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0183 - accuracy: 0.9946 - val_loss: 0.0423 - val_accuracy: 0.9912
# Epoch 166/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0314 - accuracy: 0.9899 - val_loss: 0.0461 - val_accuracy: 0.9956
# Epoch 167/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0179 - accuracy: 0.9946 - val_loss: 0.0577 - val_accuracy: 0.9912
# Epoch 168/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0228 - accuracy: 0.9946 - val_loss: 0.0442 - val_accuracy: 0.9956
# Epoch 169/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0128 - accuracy: 0.9969 - val_loss: 0.0506 - val_accuracy: 0.9912
# Epoch 170/200
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0184 - accuracy: 0.9953 - val_loss: 0.0453 - val_accuracy: 0.9912
# Epoch 171/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0185 - accuracy: 0.9907 - val_loss: 0.0539 - val_accuracy: 0.9912
# Epoch 172/200
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0225 - accuracy: 0.9907 - val_loss: 0.0519 - val_accuracy: 0.9912
# Epoch 173/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0255 - accuracy: 0.9914 - val_loss: 0.0503 - val_accuracy: 0.9912
# Epoch 174/200
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0165 - accuracy: 0.9961 - val_loss: 0.0564 - val_accuracy: 0.9912
# Epoch 175/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0134 - accuracy: 0.9953 - val_loss: 0.0513 - val_accuracy: 0.9956
# Epoch 176/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0191 - accuracy: 0.9930 - val_loss: 0.0469 - val_accuracy: 0.9956
# Epoch 177/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0177 - accuracy: 0.9953 - val_loss: 0.0491 - val_accuracy: 0.9956
# Epoch 178/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0171 - accuracy: 0.9922 - val_loss: 0.0576 - val_accuracy: 0.9956
# Epoch 179/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0109 - accuracy: 0.9977 - val_loss: 0.0582 - val_accuracy: 0.9956
# Epoch 180/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0173 - accuracy: 0.9953 - val_loss: 0.0572 - val_accuracy: 0.9912
# Epoch 181/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0181 - accuracy: 0.9946 - val_loss: 0.0663 - val_accuracy: 0.9912
# Epoch 182/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0190 - accuracy: 0.9938 - val_loss: 0.0672 - val_accuracy: 0.9912
# Epoch 183/200
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0209 - accuracy: 0.9946 - val_loss: 0.0577 - val_accuracy: 0.9912
# Epoch 184/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0234 - accuracy: 0.9946 - val_loss: 0.0651 - val_accuracy: 0.9912
# Epoch 185/200
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0289 - accuracy: 0.9922 - val_loss: 0.0584 - val_accuracy: 0.9912
# Epoch 186/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0222 - accuracy: 0.9914 - val_loss: 0.0479 - val_accuracy: 0.9956
# Epoch 187/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0204 - accuracy: 0.9938 - val_loss: 0.0466 - val_accuracy: 0.9956
# Epoch 188/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0221 - accuracy: 0.9938 - val_loss: 0.0412 - val_accuracy: 0.9956
# Epoch 189/200
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0105 - accuracy: 0.9984 - val_loss: 0.0400 - val_accuracy: 0.9956
# Epoch 190/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0188 - accuracy: 0.9953 - val_loss: 0.0335 - val_accuracy: 0.9956
# Epoch 191/200
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0289 - accuracy: 0.9907 - val_loss: 0.0318 - val_accuracy: 0.9956
# Epoch 192/200
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0248 - accuracy: 0.9899 - val_loss: 0.0336 - val_accuracy: 0.9956
# Epoch 193/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0230 - accuracy: 0.9938 - val_loss: 0.0355 - val_accuracy: 0.9912
# Epoch 194/200
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0135 - accuracy: 0.9977 - val_loss: 0.0426 - val_accuracy: 0.9956
# Epoch 195/200
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0228 - accuracy: 0.9938 - val_loss: 0.0522 - val_accuracy: 0.9912
# Epoch 196/200
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0278 - accuracy: 0.9899 - val_loss: 0.0575 - val_accuracy: 0.9912
# Epoch 197/200
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0269 - accuracy: 0.9930 - val_loss: 0.0488 - val_accuracy: 0.9956
# Epoch 198/200
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0241 - accuracy: 0.9922 - val_loss: 0.0733 - val_accuracy: 0.9912
# Epoch 199/200
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0279 - accuracy: 0.9907 - val_loss: 0.0608 - val_accuracy: 0.9956
# Epoch 200/200
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0146 - accuracy: 0.9938 - val_loss: 0.0587 - val_accuracy: 0.9956

# %%
print('-----------------EVAUATION----------------')
loss, accuracy = model.evaluate(processed_X_test, y_test)
print('LOSS: ', loss)
print("Test ACCURACY: ", accuracy)
# Out:
# -----------------EVAUATION----------------
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0066 - accuracy: 0.9966
# LOSS:  0.006598192732781172
# ACCURACY:  0.9965792298316956

# %%
loss, accuracy = model.evaluate(processed_X_train, y_train)
print('LOSS: ', loss)
print("Train ACCURACY: ", accuracy)
# Out:
# 41/41 [==============================] - 0s 1ms/step - loss: 8.6004e-04 - accuracy: 1.0000
# LOSS:  0.0008600371074862778
# Train ACCURACY:  1.0

# %%
loss, accuracy = model.evaluate(processed_X_val, y_val)
print('LOSS: ', loss)
print("Train ACCURACY: ", accuracy)
# Out:
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0587 - accuracy: 0.9956
# LOSS:  0.05874311178922653
# Train ACCURACY:  0.9955947399139404

# %%
model.save('FNN_model.keras')
